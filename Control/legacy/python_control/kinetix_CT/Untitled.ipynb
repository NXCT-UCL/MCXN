# %%
import pycromanager as pycro

# %%
pip install pycromanager --upgrade
# Out:
# ...
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -portlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mportlib-metadata (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
core = pycro.Core()
print(core)

# %%
path = 'D:/23_09_18/'
nFrames = '1'
fname = 'Im_1000ms'

# %%
with pycro.Acquisition(directory='./', name='acquisition_name', debug=True) as acq:
    events = []
    for index, proj in enumerate(np.arange(start=0, stop=nFrames, step=1)):
        evt = {
            'axes': {'theta': index},
            'theta': proj}
        acq.acquire(evt)
# Out:
# DEBUG: returning cached bridge for port 4827 thread MainThread
# DEBUG: returning cached bridge for port 4827 thread MainThread
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# C:\Users\AXIMAD~1\AppData\Local\Temp/ipykernel_2064/3634184932.py in <module>
# ----> 1 with pycro.Acquisition(directory='./', name='acquisition_name', debug=True) as acq:
#       2     events = []
#       3     for index, proj in enumerate(np.arange(start=0, stop=nFrames, step=1)):
#       4         evt = {
#       5             'axes': {'theta': index},
#
# ~\AppData\Roaming\Python\Python39\site-packages\pycromanager\acquisition\acq_constructor.py in __new__(cls, directory, name, image_process_fn, event_generation_hook_fn, pre_hardware_hook_fn, post_hardware_hook_fn, post_camera_hook_fn, notification_callback_fn, image_saved_fn, napari_viewer, debug, **kwargs)
# ...
